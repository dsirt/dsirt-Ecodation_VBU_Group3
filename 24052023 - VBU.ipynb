# %%
#Matplotlib ile Veri Görselleştirme
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10, 100, 30)
df10 = pd.DataFrame({"C1" : col1, "C2" : col2})
df10
# Out:
#             C1  C2
# 0    10.000000  11
# 1    13.103448  55
# 2    16.206897  81
# 3    19.310345  29
# 4    22.413793  67
# 5    25.517241  40
# 6    28.620690  27
# 7    31.724138  99
# 8    34.827586  58
# 9    37.931034  65
# 10   41.034483  92
# 11   44.137931  72
# 12   47.241379  63
# 13   50.344828  89
# 14   53.448276  66
# 15   56.551724  89
# 16   59.655172  75
# 17   62.758621  12
# 18   65.862069  12
# 19   68.965517  90
# 20   72.068966  63
# 21   75.172414  13
# 22   78.275862  31
# 23   81.379310  37
# 24   84.482759  88
# 25   87.586207  68
# 26   90.689655  79
# 27   93.793103  19
# 28   96.896552  11
# 29  100.000000  25

# %%
df10 = df10.drop([17,18,19], axis = 0)
df10
# Out:
#             C1  C2
# 0    10.000000  11
# 1    13.103448  55
# 2    16.206897  81
# 3    19.310345  29
# 4    22.413793  67
# 5    25.517241  40
# 6    28.620690  27
# 7    31.724138  99
# 8    34.827586  58
# 9    37.931034  65
# 10   41.034483  92
# 11   44.137931  72
# 12   47.241379  63
# 13   50.344828  89
# 14   53.448276  66
# 15   56.551724  89
# 16   59.655172  75
# 20   72.068966  63
# 21   75.172414  13
# 22   78.275862  31
# 23   81.379310  37
# 24   84.482759  88
# 25   87.586207  68
# 26   90.689655  79
# 27   93.793103  19
# 28   96.896552  11
# 29  100.000000  25

# %%
df10.drop([16], axis = 0, inplace = True)
df10
# Out:
#             C1  C2
# 0    10.000000  11
# 1    13.103448  55
# 2    16.206897  81
# 3    19.310345  29
# 4    22.413793  67
# 5    25.517241  40
# 6    28.620690  27
# 7    31.724138  99
# 8    34.827586  58
# 9    37.931034  65
# 10   41.034483  92
# 11   44.137931  72
# 12   47.241379  63
# 13   50.344828  89
# 14   53.448276  66
# 15   56.551724  89
# 20   72.068966  63
# 21   75.172414  13
# 22   78.275862  31
# 23   81.379310  37
# 24   84.482759  88
# 25   87.586207  68
# 26   90.689655  79
# 27   93.793103  19
# 28   96.896552  11
# 29  100.000000  25

# %%
df10.drop(df10.index[5], inplace = True)
df10
# Out:
#             C1  C2
# 0    10.000000  11
# 1    13.103448  55
# 2    16.206897  81
# 3    19.310345  29
# 4    22.413793  67
# 6    28.620690  27
# 7    31.724138  99
# 8    34.827586  58
# 9    37.931034  65
# 10   41.034483  92
# 11   44.137931  72
# 12   47.241379  63
# 13   50.344828  89
# 14   53.448276  66
# 15   56.551724  89
# 20   72.068966  63
# 21   75.172414  13
# 22   78.275862  31
# 23   81.379310  37
# 24   84.482759  88
# 25   87.586207  68
# 26   90.689655  79
# 27   93.793103  19
# 28   96.896552  11
# 29  100.000000  25

# %%
df10 = df10.iloc[3:,]
df10
# Out:
#             C1  C2
# 3    19.310345  29
# 4    22.413793  67
# 6    28.620690  27
# 7    31.724138  99
# 8    34.827586  58
# 9    37.931034  65
# 10   41.034483  92
# 11   44.137931  72
# 12   47.241379  63
# 13   50.344828  89
# 14   53.448276  66
# 15   56.551724  89
# 20   72.068966  63
# 21   75.172414  13
# 22   78.275862  31
# 23   81.379310  37
# 24   84.482759  88
# 25   87.586207  68
# 26   90.689655  79
# 27   93.793103  19
# 28   96.896552  11
# 29  100.000000  25

# %%
import matplotlib as mpl
# %matplotlib inline

# %%
plt.style.use('seaborn-darkgrid') #Tema belirleme

# %%
#Çizgi Grafikleri (Line Charts)

# %%
x = np.array([1,2,3,4,5,6])
y = np.power(x, 3)
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
mpl.rcParams.update(mpl.rcParamsDefault) #Default matplotlib ayarlarını geri getirmek

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
plt.style.use('seaborn-darkgrid') #Tema belirleme
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y, 'b-')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y, 'r-')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'go')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'ro')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'r^')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'rv')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
#Multiple data

# %%
plt.figure(figsize = (10,5))
x = np.array([1,2,3,4,5,6])
y1 = np.power(x, 2)
y2 = np.power(x, 3)
plt.plot(x, y1, 'b-', label = '$y1 = x^2$')
plt.plot(x, y2, 'r-', label = '$y2 = x^3$')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()
plt.tight_layout()
plt.show()

# %%
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (10, 6))
plt.plot(x, np.sin(x), label = '$Sin(X)$')
plt.plot(x, np.cos(x), label = '$Cos(X)$')
plt.xlabel(r'$X$', fontsize = 18)
plt.ylabel(r'$Y$', fontsize = 18)
plt.title('$Sin(X) $ $ & $ $ Cos(X) $', fontsize = 14)
plt.legend(loc = 'upper right')
plt.show()

# %%
#Eksenlerin Altını Boyamak
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (10, 6))
plt.plot(x, np.sin(x), label = '$Sin(X)$')
plt.plot(x, np.cos(x), label = '$Cos(X)$')
plt.fill_between(x, 0, np.sin(x))
plt.fill_between(x, 0, np.cos(x))
plt.xlabel(r'$X$', fontsize = 18)
plt.ylabel(r'$Y$', fontsize = 18)
plt.title('$Sin(X) $ $ & $ $ Cos(X) $', fontsize = 14)
plt.legend(loc = 'lower left')
plt.show()

# %%
plt.figure(figsize = (14,6))
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.subplot(1,2,1)
plt.plot(x, y1)
plt.subplot(1,2,2)
plt.plot(x, y2)
plt.show()

# %%
plt.figure(figsize = (14,6))
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.subplot(2,1,1)
plt.plot(x, y1, 'b-')
plt.subplot(2,1,2)
plt.plot(x, y2, 'r-')
plt.show()

# %%
#ÖDEV : 9lu subplot çalışması. power(x, 2), power(x, 3), sin(x), cos(x), tan(x), tanh(x), 
#sinh(x), cosh(x), exp(x). fig1, ax1 = plt.subplots(nrows = 3, ncols = 3, ....)
#ax1[0][0].plot(x, y1,......)

# %%
#Bar Graphs (Çubuk Grafikleri)

# %%
id1 = np.arange(1,10)
score = np.arange(20, 110, 10)
plt.bar(id1, score)
plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
id1 = np.arange(1,10)
score = np.arange(20, 110, 10)
plt.figure(figsize = (8,5))
ax = plt.axes()
ax.set_facecolor("#ECF0F1")
plt.bar(id1, score, color = '#FFA726')
plt.xlabel(r'$Student $ $ ID $')
plt.ylabel(r'$Score$')
plt.show()

# %%
#Multiple data

# %%
x1 = [1,3,5,7]
x2 = [2,4,6,8]
y1 = [7,7,7,7]
y2 = [17,18,29,40]
plt.figure(figsize = (8,6))
ax = plt.axes()
ax.set_facecolor('white')
plt.bar(x1, y1, label = 'First', color = '#42B300')
plt.bar(x2, y2, label = 'Second', color = '#94E413')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar$ $Chart$')
plt.legend()
plt.show()

# %%
#Yatay (Horizontal) Bar Chart
Age = [28,33,43,45,57]
Name = ['Aykun', 'Fatma', 'Mert', 'Tuğçe', 'Doğu']
plt.barh(Name, Age, color = 'yellowgreen')
plt.show()

# %%
#Grafikteki Çubukları İnceltme

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])
plt.figure(figsize = (8,4))
plt.bar(num1, num1**2, width = 0.2, color = '#FF6F00')
plt.bar(num2, num2**2, width = 0.2, color = '#FFB300')
plt.show()

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])
plt.figure(figsize = (8,4))
plt.bar(num1, num1**2, width = 0.2, color = '#FF6F00')
plt.bar(num2, num2**2, width = 0.2, color = '#FFB300')
for x, y in zip(num1, num1**2):
    plt.text(x, y + 0.05, '%d' % y, ha = 'center', va = 'bottom')
for x, y in zip(num2, num2**2):
    plt.text(x, y + 0.05, '%d' % y, ha = 'center', va = 'bottom')
plt.show()

# %%
#İkiz grafikler
x = np.arange(1, 21)
plt.figure(figsize = (16,8))
y1 = np.random.uniform(0.1, 0.7, 20)
y2 = np.random.uniform(0.1, 0.7, 20)

plt.bar(x, +y1, facecolor = '#C0CA33', edgecolor = 'white')
plt.bar(x, -y2, facecolor = '#FF9800', edgecolor = 'white')

for x, y in zip(x, y1):
    plt.text(x, y+0.05, '%.2f' % y, ha = 'center', va = 'bottom', fontsize = 10)
    
plt.xlim(0,21)
plt.ylim(-1.25, +1.25)
plt.show()

# %%
#Stacked Vertical Bar

# %%
plt.style.use('seaborn-darkgrid')

# %%
x1 = ['Aykun', 'Fatma', 'Mert', 'Tuğçe']
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Satışa Açık Biletler', width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Satışa Kapalı Biletler', width = 0.5, bottom = y1, color = '#FFB300')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar$ $Chart$')
plt.legend()
plt.show()

# %%
x1 = ['Aykun', 'Fatma', 'Mert', 'Tuğçe']
y1 = np.array([17, 18, 29, 40])
y2 = np.array([20, 21, 22, 23])
y3 = np.array([5, 9, 11, 12])
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Satışa Açık Biletler', width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Satışa Kapalı Biletler', width = 0.5, bottom = y1, color = '#FFB300')
plt.bar(x1, y3, label = 'İptal Edilen Biletler', width = 0.5, bottom = y1 + y2, color = '#F7DC6F')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar$ $Chart$')
plt.legend()
plt.show()

# %%
x1 = ['Aykun', 'Fatma', 'Mert', 'Tuğçe']
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]
plt.figure(figsize = (8,5))
plt.barh(x1, y1, label = 'Satışa Açık Biletler', color = '#FF6F00')
plt.barh(x1, y2, label = 'Satışa Kapalı Biletler', left = y1, color = '#FFB300')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar$ $Chart$')
plt.legend()
plt.show()

# %%
#Değerleri Görüntüleme
x1 = ['Aykun', 'Fatma', 'Mert', 'Tuğçe']
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Satışa Açık Biletler', width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Satışa Kapalı Biletler', width = 0.5, bottom = y1, color = '#FFB300')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar$ $Chart$')

for x, y in zip(x1, y1):
    plt.text(x, y - 10, '%d' % y, ha = 'center', va = 'bottom')
    
for x, y, z in zip(x1, y2, y1):
    plt.text(x, y + z - 10, '%d' % y, ha = 'center', va = 'bottom')

plt.legend()
plt.show()

# %%
x1 = ['Aykun', 'Fatma', 'Mert', 'Tuğçe']
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]
plt.figure(figsize = (8,5))
plt.barh(x1, y1, label = 'Satışa Açık Biletler', color = '#FF6F00')
plt.barh(x1, y2, label = 'Satışa Kapalı Biletler', left = y1, color = '#FFB300')

for x, y in zip(x1, y1):
    plt.text(y-10, x, '%d' % y, ha = 'center', va = 'bottom')
    
for x, y, z in zip(x1, y2, y1):
    plt.text(y+z-10, x, '%d' % y, ha = 'center', va = 'bottom')

plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar$ $Chart$')
plt.legend()
plt.show()
